# %% [markdown]
# 4. Ask the user to enter their favourite colour. If they enter “red”, “RED” or
# “Red” display the message “I like red too”, otherwise display the message
# “I don’t like [colour], I prefer red”.

# %%
colour = input("Enter your favorite colour : ")
lowercase = colour.lower()
upper = colour.upper()
titlecase = colour.title()
print(lowercase, upper, titlecase)
# Out:
# Enter your favorite colour : RoSe
# rose ROSE Rose

# %%
if colour == lowercase or colour == upper or colour == titlecase:
    print("I like {} too ".format(colour))
else:
    print("I don't like that {}. I prefer {}".format(colour, lowercase))
# Out:
# I don't like that RoSe. I prefer rose

# %% [markdown]
# 12. Write a program to check whether an years is leap year or not.

# %%
yr=int(input("Enter the year"))
if yr%100==0:
    if yr%400==0:
          print("Entered year is leap year")
    else:
          print("Entered year is not a leap year")
else:
    if yr%4==0:
         print("Entered year is leap year")  
    else:
        print("Entered year is not a leap year")
# Out:
# Enter the year345
# Entered year is not a leap year

# %% [markdown]
#  ### Lists

# %% [markdown]
# 1. What is the difference between append and extend?
# <pre>
# .append() adds an object to the end of a list.
# a = [1,2,3]
# a.append(4)
# a #=> [1, 2, 3, 4]
#
# This also means appending a list adds that whole list as a single element, rather than appending each of its values.
#
# a.append([5,6])
# a #=> [1, 2, 3, 4, [5, 6]]
#
# .extend() adds each value from a 2nd list as its own element. So extending a list with another list combines their values.
#
# b = [1,2,3]
# b.extend([5,6])
#
# b #=> [1, 2, 3, 5, 6]

# %%
# 2. Do python lists store values or pointers?

# Python lists don’t store values themselves. 
# They store pointers to values stored elsewhere in memory. 
# This allows lists to be mutable.

# Here we initialize values 1 and 2, then create a list including the values 1 and 2.
print(f'id(1) : {id(1)}'); print(f'id(2) : {id(2)}')
a = [1,2,3]
print(f'id(a) : {id(a)}')
print(f'id(a[0]) : {id(a[0])}')
print(f'id(a[1]) : {id(a[1])}')
# Out:
# id(1) : 2093346744624
# id(2) : 2093346744656
# id(a) : 2093428233728
# id(a[0]) : 2093346744624
# id(a[1]) : 2093346744656

# %% [markdown]
# 3. What does “del” do?
#
# del removes an item from a list given its index or the complete list itself.
#
# Syntax
#
# <pre>
# del list_name[index]   # delete specific element
# del list_name          #delete the complete list

# %% [markdown]
# 4. What is the difference between “remove” and “pop”?
#
# .remove()<br>
# .remove() used to remove a specific value from the list. The remove method accepts the element value as a parameter and deletes the first occurrence of the value from the list. The remove method return a None value.
#
# Syntax
#
# list_name.remove(value)
#
#
# .pop()<br>
# .pop() removes an object by its index. By default, the pop() method is used to remove the last element from the list. But it also accepts an optional parameter that represents the index number that supposed to pop out or delete from the list.
#
# The pop() method also returns the value that it poped out or delete from the list.
#
# Syntax
#
# list_name.pop(index)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 5. What is the output of this code?

my_list = [1,2,3,4,5,6,7]
del my_list[3] #delete 4 from the list
print(my_list)
del my_list         #delete the complete list
my_list
# Out:
# [1, 2, 3, 5, 6, 7]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <module>
#       5 print(my_list)
#       6 del my_list         #delete the complete list
# ----> 7 my_list
#
# NameError: name 'my_list' is not defined

# %%
#6. What is the output of this code?

my_list = [1,1,2,2,3,3]
my_list.remove(2)        #remove the first 2 from the list
print(my_list)
my_list.remove(12) # If the specified value does not exist in the list the remove method throw a ValueError.
# Out:
# [1, 1, 2, 3, 3]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <module>
#       4 my_list.remove(2)        #remove the first 2 from the list
#       5 print(my_list)
# ----> 6 my_list.remove(12)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# 7. Difference between indexing and Slicing?
#
# ![image.png](attachment:image.png)

# %%
# 8. What will sorted() will do to a list

# %% [markdown]
# 9. Difference between sort() and sorted()
#
# Sort() and sorted() are two different functions. In fact, the sort() is a list method whereas sorted() is a built-in function.
#
# Even both sort() and sorted() sorts the elements in the list, they are different.
# <pre>
# sorted() Built-In Function
# sort() Python List Method

# %%
listObj=[34,17,56]
print(sorted(listObj))
listObj
# Out:
# [17, 34, 56]
# [34, 17, 56]

# %%
listObj=[34,17,56]
listObj.sort()
listObj
# Out:
# [17, 34, 56]

# %%
10. What is the output?

listObj=[34,17,56]
sort(listObj, reverse=True)
listObj
# Out:
# Object `output` not found.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <module>
#       1 get_ipython().run_line_magic('pinfo', 'output')
#       3 listObj=[34,17,56]
# ----> 4 sort(listObj, reverse=True)
#       5 listObj
#
# NameError: name 'sort' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 11. Difference between copy and deepcopy?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Why does this happen?
#
# Creating a shallow copy does create a new object in memory, but it’s filled with the same references to existing objects that the previous list has.
#
# Creating a deep copy creates copies of the original objects and points to these new versions. So the new list is completely unaffected by changes to the old list and vice versa.

# %% [markdown]
# 12. How to check whether the list is empty or not?
#
# We can check by the below mentioned three methods.
# 1. len()-If length is zero means list is empty
# 2. if not listname:
# 3. compare against the empty list

# %%
num1=[]
print (len(num1))
# Out:
# 0

# %%
num1=[]
if not num1:
    print ("list is empty")
# Out:
# list is empty

# %%
num1=[]
num2=[]
if num1==num2:
    print ("list is empty")
# Out:
# list is empty

# %% [markdown]
# 13. How to find the first and last element of the list?
#
# Using Indexing, we can find the first and last element of the list.
# <pre>
# num[0]-returns first element
# num[-1]-returns last element

# %%
# 15. Create a list of two sports. Ask the user what their favourite sport is and add this to the end of the list. Sort the 
# list and display it.

sports_list = ['cricket','tennis']
fav_sport = input("Enter your favorite sport : ")
sports_list.append(fav_sport)
sports_list
# Out:
# Enter your favorite sport : chess
# ['cricket', 'tennis', 'chess']

# %%
fruit = ['pear', 'orange', 'apple', 'grapefruit', 'apple', 'pear']
fruit.index('apple')
fruit.index('pear')
# Out:
# 0

# %%
fruit = ['pear', 'orange', 'apple', 'grapefruit', 'apple', 'pear']
print(fruit.index('apple'))
fruit.index('pear')
# Out:
# 2
# 0

# %% [markdown]
# 17. How to concatenate two lists
#
# The + operator will concatenate 2 lists.
#
# <pre>
# one = ['a', 'b', 'c']
# two = [1, 2, 3]
# one+two

# %%
# 18. Create a list of six school subjects. Ask the user which of these subjects they don’t like. Delete the subject 
# they have chosen from the list before you display the list again.

subj = ['english','physics','chemistry','maths','biology','computer science']
print(subj)
dislike = input("Which subject you don't like? ")
getrid_index = subj.index(dislike)
del subj[getrid_index]
subj
# Out:
# ['english', 'physics', 'chemistry', 'maths', 'biology', 'computer science']
# Which subject you don't like? maths
# ['english', 'physics', 'chemistry', 'biology', 'computer science']

# %%
# 19. Enter a list of ten colours. Ask the user for a starting number between 0 and 4 and an end number between 5 and 9. Display
# the list for those colours between the start and end numbers the user input.

colors = ['red','green','pink','violet','blue','yellow','white','purple','orange','black']
print(colors)
start = int(input("Enter a starting number (0-4) : "))
end = int(input("Enter a ending number (5-9) : "))
colors[start:end]
# Out:
# ['red', 'green', 'pink', 'violet', 'blue', 'yellow', 'white', 'purple', 'orange', 'black']
# Enter a starting number (0-4) : 3
# Enter a ending number (5-9) : 4
# ['violet']

# %%
# 20. Create a list of four three-digit numbers. Display the list to the user, showing each item from the list on a separate 
# line. Ask the user to enter a three-digit number. If the number they have typed in matches one in the list, display the 
# position of that number in the list with a message "<number> is in Position <indexPosition>", otherwise display the message 
# “number is not in the list”.

nums = [345, 123, 234, 567]
for aNum in nums:
    print(aNum)
select_num = int(input("Enter a three digit number : "))
if select_num in nums:
    print("{0} is in Position {1}".format(select_num, nums.index(select_num)))
else:
    print("{0} is not in the list".format(select_num))
# Out:
# 345
# 123
# 234
# 567
# Enter a three digit number : eee
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <module>
#       7 for aNum in nums:
#       8     print(aNum)
# ----> 9 select_num = int(input("Enter a three digit number : "))
#      10 if select_num in nums:
#      11     print("{0} is in Position {1}".format(select_num, nums.index(select_num)))
#
# ValueError: invalid literal for int() with base 10: 'eee'

# %%
nums = [345, 123, 234, 567]
for aNum in nums:
    print(aNum)
select_num = int(input("Enter a three digit number : "))
if select_num in nums:
    print("{0} is in Position {1}".format(select_num, nums.index(select_num)))
else:
    print("{0} is not in the list".format(select_num))
# Out:
# 345
# 123
# 234
# 567
# Enter a three digit number : 111
# 111 is not in the list

# %%
# 21. Ask the user to enter the names of three people they want to invite to a party and store them in a list. 
# After they have entered all three names, ask them if they want to add another. If they give yes, allow them to add these list of
# names girish, bhavana, samyuktha, terecy, nidhish to the existing list and if they answer “no” display how many people they 
# have invited to the party. Print the list. Now, ask them to type in one of the names on the list. Display the position of that name in the list. 
# Ask the user if they still want that person to come to the party. If they answer “no”, delete that entry from the list and 
# display the list again.

name1 = input("enter 1st name of three people you want to invite to a party : ")
name2 = input("enter 2nd name : ")
name3 = input("enter 3rd name : ")
party =[name1, name2, name3]
addlist = ['girish', 'bhavana', 'samyuktha', 'terecy', 'nidhish']
another = input("Do you want to invite another (yes/no) : ")
if another == 'yes':
    party = party.append[addlist]
else:
    print("You have", len(party), "people coming to your party")
# Out:
# enter 1st name of three people you want to invite to a party : hems
# enter 2nd name : reta
# enter 3rd name : bala
# Do you want to invite another (yes/no) : yes
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <module>
#      13 another = input("Do you want to invite another (yes/no) : ")
#      14 if another == 'yes':
# ---> 15     party = party.append[addlist]
#      16 else:
#      17     print("You have", len(party), "people coming to your party")
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
name1 = input("enter 1st name of three people you want to invite to a party : ")
name2 = input("enter 2nd name : ")
name3 = input("enter 3rd name : ")
party =[name1, name2, name3]
addlist = ['girish', 'bhavana', 'samyuktha', 'terecy', 'nidhish']
another = input("Do you want to invite another (yes/no) : ")
if another == 'yes':
    party = party.append(addlist)
else:
    print("You have", len(party), "people coming to your party")

print(party)
# Out:
# enter 1st name of three people you want to invite to a party : weew
# enter 2nd name : were
# enter 3rd name : rtr
# Do you want to invite another (yes/no) : yes
# None

# %%
name1 = input("enter 1st name of three people you want to invite to a party : ")
name2 = input("enter 2nd name : ")
name3 = input("enter 3rd name : ")
party =[name1, name2, name3]
addlist = ['girish', 'bhavana', 'samyuktha', 'terecy', 'nidhish']
another = input("Do you want to invite another (yes/no) : ")
if another == 'yes':
    party = party.extend(addlist)
else:
    print("You have", len(party), "people coming to your party")

print(party)
# Out:
# enter 1st name of three people you want to invite to a party : wert
# enter 2nd name : ert
# enter 3rd name : bere
# Do you want to invite another (yes/no) : yes
# None

# %%
name1 = input("enter 1st name of three people you want to invite to a party : ")
name2 = input("enter 2nd name : ")
name3 = input("enter 3rd name : ")
party =[name1, name2, name3]
addlist = ['girish', 'bhavana', 'samyuktha', 'terecy', 'nidhish']
another = input("Do you want to invite another (yes/no) : ")
if another == 'yes':
    party.extend(addlist)
else:
    print("You have", len(party), "people coming to your party")

print(party)
# Out:
# enter 1st name of three people you want to invite to a party : tweek
# enter 2nd name : twitter
# enter 3rd name : facebook
# Do you want to invite another (yes/no) : yes
# ['tweek', 'twitter', 'facebook', 'girish', 'bhavana', 'samyuktha', 'terecy', 'nidhish']

# %%
name1 = input("enter 1st name of three people you want to invite to a party : ")
name2 = input("enter 2nd name : ")
name3 = input("enter 3rd name : ")
party =[name1, name2, name3]
addlist = ['girish', 'bhavana', 'samyuktha', 'terecy', 'nidhish']
another = input("Do you want to invite another (yes/no) : ")
if another == 'yes':
    party.append(addlist)
else:
    print("You have", len(party), "people coming to your party")
print(party)
# Out:
# enter 1st name of three people you want to invite to a party : 123
# enter 2nd name : 344
# enter 3rd name : 544
# Do you want to invite another (yes/no) : yes
# ['123', '344', '544', ['girish', 'bhavana', 'samyuktha', 'terecy', 'nidhish']]

# %%
name1 = input("enter 1st name of three people you want to invite to a party : ")
name2 = input("enter 2nd name : ")
name3 = input("enter 3rd name : ")
party =[name1, name2, name3]
addlist = ['girish', 'bhavana', 'samyuktha', 'terecy', 'nidhish']
another = input("Do you want to invite another (yes/no) : ")
if another == 'yes':
    party.extend(addlist)
else:
    print("You have", len(party), "people coming to your party")
print(party)
select_person = input("Type one of the names in the list : ")
print("{0} is in Position {1}".format(select_person, party.index(select_person)))
stillcome = input("Do you still want that person to come to the party (yes/no) : ")
if stillcome == 'no':
    party.remove(select_person)
print(party)
# Out:
# enter 1st name of three people you want to invite to a party : raj
# enter 2nd name : somesh
# enter 3rd name : mayank
# Do you want to invite another (yes/no) : yes
# ['raj', 'somesh', 'mayank', 'girish', 'bhavana', 'samyuktha', 'terecy', 'nidhish']
# Type one of the names in the list : mayank
# mayank is in Position 2
# Do you still want that person to come to the party (yes/no) : yes
# ['raj', 'somesh', 'mayank', 'girish', 'bhavana', 'samyuktha', 'terecy', 'nidhish']
